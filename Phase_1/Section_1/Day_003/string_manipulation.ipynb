# %% [markdown]
# # String Manipulation
# - String is a sequence of characters

# %%
# String as a data structure

# %%
my_string = "hello"
my_string
# Out:
# 'hello'

# %%
# Accessing character in a string
my_string[1] # accessing 'e'
# Out:
# 'e'

# %%
### Slicing
# - start, end, step

# %%
my_string[1:4] # 'ell'
# Out:
# 'ell'

# %%
# Concatination
string1 = "hello"
string2 = "world"
print(string1 + string2)
# Out:
# helloworld

# %%
print(string1 + ' ' + string2)
# Out:
# hello world

# %%
# f-string concatination
print(f"{string1} {string2}")
# Out:
# hello world

# %%
# iterate through string
for char in string1:
    print (char)
# Out:
# h
# e
# l
# l
# o
