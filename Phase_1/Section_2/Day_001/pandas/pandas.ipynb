# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Creating Series

# %%
pd.Series(data = [3, 3.5, "anita"])
# Out:
# 0        3
# 1      3.5
# 2    anita
# dtype: object

# %%
pd.Series(data = [3, 7.7, "anita", 3, 7], index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a        3
# b      7.7
# c    anita
# d        3
# e        7
# dtype: object

# %%
# Write 10 names of students with custom index
pd.Series(data = ["Anita", "Krishna", "Pradip", "Sunita", "Anup", "Suman", "Desmond", "Erum", "Siddhartha", "Kuber"],
          index = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"])
# Out:
# a         Anita
# b       Krishna
# c        Pradip
# d        Sunita
# e          Anup
# f         Suman
# g       Desmond
# h          Erum
# i    Siddhartha
# j         Kuber
# dtype: object

# %% [markdown]
# ### Creating dictionary from Series
